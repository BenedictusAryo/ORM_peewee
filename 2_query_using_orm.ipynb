# %% [markdown]
# # SQL Query using Peewee ORM

# %%
# This code will convert sqlite db to pewee models in file peewee_chinook_models.py
# !python -m pwiz -e sqlite database/chinook.db > peewee_chinook_models.py

# %%
from peewee_chinook_models import Albums

# %%
list(Albums.select().dicts())
# Out:
# [{'album_id': 1, 'artist': 1},
#  {'album_id': 4, 'artist': 1},
#  {'album_id': 2, 'artist': 2},
#  {'album_id': 3, 'artist': 2},
#  {'album_id': 5, 'artist': 3},
#  {'album_id': 6, 'artist': 4},
#  {'album_id': 7, 'artist': 5},
#  {'album_id': 8, 'artist': 6},
#  {'album_id': 34, 'artist': 6},
#  {'album_id': 9, 'artist': 7},
#  {'album_id': 10, 'artist': 8},
#  {'album_id': 11, 'artist': 8},
#  {'album_id': 271, 'artist': 8},
#  {'album_id': 12, 'artist': 9},
#  {'album_id': 13, 'artist': 10},
#  {'album_id': 14, 'artist': 11},
#  {'album_id': 15, 'artist': 11},
#  {'album_id': 16, 'artist': 12},
#  {'album_id': 17, 'artist': 12},
#  {'album_id': 18, 'artist': 13},
#  {'album_id': 19, 'artist': 14},
#  {'album_id': 20, 'artist': 15},
#  {'album_id': 21, 'artist': 16},
#  {'album_id': 22, 'artist': 16},
#  {'album_id': 23, 'artist': 17},
#  {'album_id': 24, 'artist': 18},
#  {'album_id': 25, 'artist': 18},
#  {'album_id': 26, 'artist': 19},
#  {'album_id': 27, 'artist': 19},
# ...
